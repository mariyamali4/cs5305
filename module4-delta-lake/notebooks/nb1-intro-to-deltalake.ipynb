# %%
# %run ../../common_notebooks/setup_spark_connection.ipynb
from pyspark.sql.functions import col, lit, when, upper, avg

print(f"Spark version: {spark.version}")
# Out:
# Spark version: 4.0.1

# %%
df = spark.createDataFrame([(1, "Starter"), (2, "Pro")], ["id", "plan"])
df.write.format("delta").mode("overwrite").save("/tmp/delta-tables/table2")
print("Delta table created successfully!")
# Out:
# Delta table created successfully!

# %%
# 1. Read the Delta table we created
print("=== Reading Delta Table ===")
delta_df = spark.read.format("delta").load("/tmp/delta-tables/table2")
delta_df.show()
# Out:
# === Reading Delta Table ===
# +---+-------+
# | id|   plan|
# +---+-------+
# |  1|Starter|
# |  2|    Pro|
# +---+-------+

# %%
# 2. Check table schema and metadata
print("\n=== Table Schema ===")
delta_df.printSchema()
print("\n=== Table Count ===")
print(f"Number of records: {delta_df.count()}")
# Out:
# === Table Schema ===
# root
#  |-- id: long (nullable = true)
#  |-- plan: string (nullable = true)
#
#
# === Table Count ===
# Number of records: 2

# %%
# 4. Add more data (Append mode)
print("\n=== Appending New Data ===")
new_data = spark.createDataFrame([(3, "Enterprise"), (4, "Basic")], ["id", "plan"])
new_data.write.format("delta").mode("append").save("/tmp/delta-tables/table2")

# Read updated table
updated_df = spark.read.format("delta").load("/tmp/delta-tables/table2")
print("Updated table:")
updated_df.show()
# Out:
# === Appending New Data ===
# Updated table:
# +---+----------+
# | id|      plan|
# +---+----------+
# |  3|Enterprise|
# |  1|   Starter|
# |  4|     Basic|
# |  2|       Pro|
# +---+----------+

# %%
from delta.tables import DeltaTable

deltaTable = DeltaTable.forPath(spark, "/tmp/delta-tables/table2")

# 5. Update existing records
print("\n=== Updating Records ===")
deltaTable.update(
    condition="id = 1",
    set={"plan": "'Starter Pro'"}
)

# Read after update
print("After update:")
spark.read.format("delta").load("/tmp/delta-tables/table2").show()
# Out:
# === Updating Records ===
# ---------------------------------------------------------------------------
# InvalidPlanInput                          Traceback (most recent call last)
# Cell In[7], line 7
#       5 # 5. Update existing records
#       6 print("\n=== Updating Records ===")
# ----> 7 deltaTable.update(
#       8     condition="id = 1",
#       9     set={"plan": "'Starter Pro'"}
#      10 )
#      12 # Read after update
#      13 print("After update:")
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\delta\connect\tables.py:153, in DeltaTable.update(self, condition, set)
#     147 plan = UpdateTable(
#     148     self._plan,
#     149     condition,
#     150     assignments
#     151 )
#     152 df = DataFrame(plan, session=self._spark)
# --> 153 return self._spark.createDataFrame(df.toPandas())
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pyspark\sql\connect\dataframe.py:1850, in DataFrame.toPandas(self)
#    1848 def toPandas(self) -> "PandasDataFrameLike":
#    1849     query = self._plan.to_proto(self._session.client)
# -> 1850     pdf, ei = self._session.client.to_pandas(query, self._plan.observations)
#    1851     self._execution_info = ei
#    1852     return pdf
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pyspark\sql\connect\client\core.py:1004, in SparkConnectClient.to_pandas(self, plan, observations)
#    1000 (self_destruct_conf,) = self.get_config_with_defaults(
#    1001     ("spark.sql.execution.arrow.pyspark.selfDestruct.enabled", "false"),
#    1002 )
#    1003 self_destruct = cast(str, self_destruct_conf).lower() == "true"
# -> 1004 table, schema, metrics, observed_metrics, _ = self._execute_and_fetch(
#    1005     req, observations, self_destruct=self_destruct
#    1006 )
#    1007 assert table is not None
#    1008 ei = ExecutionInfo(metrics, observed_metrics)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pyspark\sql\connect\client\core.py:1697, in SparkConnectClient._execute_and_fetch(self, req, observations, self_destruct)
#    1694 properties: Dict[str, Any] = {}
#    1696 with Progress(handlers=self._progress_handlers, operation_id=req.operation_id) as progress:
# -> 1697     for response in self._execute_and_fetch_as_iterator(
#    1698         req, observations, progress=progress
#    1699     ):
#    1700         if isinstance(response, StructType):
#    1701             schema = response
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pyspark\sql\connect\client\core.py:1674, in SparkConnectClient._execute_and_fetch_as_iterator(self, req, observations, progress)
#    1672     raise kb
#    1673 except Exception as error:
# -> 1674     self._handle_error(error)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pyspark\sql\connect\client\core.py:1982, in SparkConnectClient._handle_error(self, error)
#    1980     self.thread_local.inside_error_handling = True
#    1981     if isinstance(error, grpc.RpcError):
# -> 1982         self._handle_rpc_error(error)
#    1983     raise error
#    1984 finally:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pyspark\sql\connect\client\core.py:2066, in SparkConnectClient._handle_rpc_error(self, rpc_error)
#    2057                 logger.info(
#    2058                     "Disabling plan compression for the session due to "
#    2059                     "CONNECT_INVALID_PLAN.CANNOT_PARSE error."
#    2060                 )
#    2061                 self._plan_compression_threshold, self._plan_compression_algorithm = (
#    2062                     -1,
#    2063                     "NONE",
#    2064                 )
# -> 2066             raise convert_exception(
#    2067                 info,
#    2068                 status.message,
#    2069                 self._fetch_enriched_error(info),
#    2070                 self._display_server_stack_trace(),
#    2071                 status_code,
#    2072             ) from None
#    2074     raise SparkConnectGrpcException(
#    2075         message=status.message,
#    2076         grpc_status_code=status_code,
#    2077     ) from None
#    2078 else:
#
# InvalidPlanInput: No handler found for extension
#
# JVM stacktrace:
# org.apache.spark.sql.connect.common.InvalidPlanInput
# 	at org.apache.spark.sql.connect.planner.SparkConnectPlanner.$anonfun$transformRelationPlugin$3(SparkConnectPlanner.scala:253)
# 	at scala.Option.getOrElse(Option.scala:201)
# 	at org.apache.spark.sql.connect.planner.SparkConnectPlanner.transformRelationPlugin(SparkConnectPlanner.scala:253)
# 	at org.apache.spark.sql.connect.planner.SparkConnectPlanner.$anonfun$transformRelation$1(SparkConnectPlanner.scala:235)
# 	at org.apache.spark.sql.connect.service.SessionHolder.$anonfun$usePlanCache$3(SessionHolder.scala:477)
# 	at scala.Option.getOrElse(Option.scala:201)
# 	at org.apache.spark.sql.connect.service.SessionHolder.usePlanCache(SessionHolder.scala:476)
# 	at org.apache.spark.sql.connect.planner.SparkConnectPlanner.transformRelation(SparkConnectPlanner.scala:147)
# 	at org.apache.spark.sql.connect.execution.SparkConnectPlanExecution.handlePlan(SparkConnectPlanExecution.scala:74)
# 	at org.apache.spark.sql.connect.execution.ExecuteThreadRunner.handlePlan(ExecuteThreadRunner.scala:314)
# 	at org.apache.spark.sql.connect.execution.ExecuteThreadRunner.$anonfun$executeInternal$1(ExecuteThreadRunner.scala:225)
# 	at org.apache.spark.sql.connect.execution.ExecuteThreadRunner.$anonfun$executeInternal$1$adapted(ExecuteThreadRunner.scala:196)
# 	at org.apache.spark.sql.connect.service.SessionHolder.$anonfun$withSession$2(SessionHolder.scala:341)
# 	at org.apache.spark.sql.SparkSession.withActive(SparkSession.scala:804)
# 	at org.apache.spark.sql.connect.service.SessionHolder.$anonfun$withSession$1(SessionHolder.scala:341)
# 	at org.apache.spark.JobArtifactSet$.withActiveJobArtifactState(JobArtifactSet.scala:94)
# 	at org.apache.spark.sql.artifact.ArtifactManager.$anonfun$withResources$1(ArtifactManager.scala:112)
# 	at org.apache.spark.util.Utils$.withContextClassLoader(Utils.scala:186)
# 	at org.apache.spark.sql.artifact.ArtifactManager.withClassLoaderIfNeeded(ArtifactManager.scala:102)
# 	at org.apache.spark.sql.artifact.ArtifactManager.withResources(ArtifactManager.scala:111)
# 	at org.apache.spark.sql.connect.service.SessionHolder.withSession(SessionHolder.scala:340)
# 	at org.apache.spark.sql.connect.execution.ExecuteThreadRunner.executeInternal(ExecuteThreadRunner.scala:196)
# 	at org.apache.spark.sql.connect.execution.ExecuteThreadRunner.org$apache$spark$sql$connect$execution$ExecuteThreadRunner$$execute(ExecuteThreadRunner.scala:125)
# 	at org.apache.spark.sql.connect.execution.ExecuteThreadRunner$ExecutionThread.run(ExecuteThreadRunner.scala:347)

# %%
# 6. Delete records
print("\n=== Deleting Records ===")
deltaTable.delete("id = 4")

# Read after delete
print("After delete:")
spark.read.format("delta").load("/tmp/delta-tables/table2").show()

# %%
# 7. Upsert (Merge) operation
print("\n=== Upsert/Merge Operation ===")
merge_data = spark.createDataFrame([(2, "Pro Max"), (5, "Premium")], ["id", "plan"])

deltaTable.alias("target").merge(
    merge_data.alias("source"),
    "target.id = source.id"
).whenMatchedUpdate(set={"plan": "source.plan"}).whenNotMatchedInsert(values={"id": "source.id", "plan": "source.plan"}).execute()

print("After merge:")
spark.read.format("delta").load("/tmp/delta-tables/table2").show()
# Out:
# === Upsert/Merge Operation ===
# ---------------------------------------------------------------------------
# InvalidPlanInput                          Traceback (most recent call last)
# Cell In[8], line 8
#       2 print("\n=== Upsert/Merge Operation ===")
#       3 merge_data = spark.createDataFrame([(2, "Pro Max"), (5, "Premium")], ["id", "plan"])
#       5 deltaTable.alias("target").merge(
#       6     merge_data.alias("source"),
#       7     "target.id = source.id"
# ----> 8 ).whenMatchedUpdate(set={"plan": "source.plan"}).whenNotMatchedInsert(values={"id": "source.id", "plan": "source.plan"}).execute()
#      10 print("After merge:")
#      11 spark.read.format("delta").load("/tmp/delta-tables/table2").show()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\delta\connect\tables.py:609, in DeltaMergeBuilder.execute(self)
#     599 plan = MergeIntoTable(
#     600     self._target,
#     601     self._source,
#    (...)    606     self._with_schema_evolution
#     607 )
#     608 df = DataFrame(plan, session=self._spark)
# --> 609 return self._spark.createDataFrame(df.toPandas())
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pyspark\sql\connect\dataframe.py:1850, in DataFrame.toPandas(self)
#    1848 def toPandas(self) -> "PandasDataFrameLike":
#    1849     query = self._plan.to_proto(self._session.client)
# -> 1850     pdf, ei = self._session.client.to_pandas(query, self._plan.observations)
#    1851     self._execution_info = ei
#    1852     return pdf
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pyspark\sql\connect\client\core.py:1004, in SparkConnectClient.to_pandas(self, plan, observations)
#    1000 (self_destruct_conf,) = self.get_config_with_defaults(
#    1001     ("spark.sql.execution.arrow.pyspark.selfDestruct.enabled", "false"),
#    1002 )
#    1003 self_destruct = cast(str, self_destruct_conf).lower() == "true"
# -> 1004 table, schema, metrics, observed_metrics, _ = self._execute_and_fetch(
#    1005     req, observations, self_destruct=self_destruct
#    1006 )
#    1007 assert table is not None
#    1008 ei = ExecutionInfo(metrics, observed_metrics)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pyspark\sql\connect\client\core.py:1697, in SparkConnectClient._execute_and_fetch(self, req, observations, self_destruct)
#    1694 properties: Dict[str, Any] = {}
#    1696 with Progress(handlers=self._progress_handlers, operation_id=req.operation_id) as progress:
# -> 1697     for response in self._execute_and_fetch_as_iterator(
#    1698         req, observations, progress=progress
#    1699     ):
#    1700         if isinstance(response, StructType):
#    1701             schema = response
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pyspark\sql\connect\client\core.py:1674, in SparkConnectClient._execute_and_fetch_as_iterator(self, req, observations, progress)
#    1672     raise kb
#    1673 except Exception as error:
# -> 1674     self._handle_error(error)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pyspark\sql\connect\client\core.py:1982, in SparkConnectClient._handle_error(self, error)
#    1980     self.thread_local.inside_error_handling = True
#    1981     if isinstance(error, grpc.RpcError):
# -> 1982         self._handle_rpc_error(error)
#    1983     raise error
#    1984 finally:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pyspark\sql\connect\client\core.py:2066, in SparkConnectClient._handle_rpc_error(self, rpc_error)
#    2057                 logger.info(
#    2058                     "Disabling plan compression for the session due to "
#    2059                     "CONNECT_INVALID_PLAN.CANNOT_PARSE error."
#    2060                 )
#    2061                 self._plan_compression_threshold, self._plan_compression_algorithm = (
#    2062                     -1,
#    2063                     "NONE",
#    2064                 )
# -> 2066             raise convert_exception(
#    2067                 info,
#    2068                 status.message,
#    2069                 self._fetch_enriched_error(info),
#    2070                 self._display_server_stack_trace(),
#    2071                 status_code,
#    2072             ) from None
#    2074     raise SparkConnectGrpcException(
#    2075         message=status.message,
#    2076         grpc_status_code=status_code,
#    2077     ) from None
#    2078 else:
#
# InvalidPlanInput: No handler found for extension
#
# JVM stacktrace:
# org.apache.spark.sql.connect.common.InvalidPlanInput
# 	at org.apache.spark.sql.connect.planner.SparkConnectPlanner.$anonfun$transformRelationPlugin$3(SparkConnectPlanner.scala:253)
# 	at scala.Option.getOrElse(Option.scala:201)
# 	at org.apache.spark.sql.connect.planner.SparkConnectPlanner.transformRelationPlugin(SparkConnectPlanner.scala:253)
# 	at org.apache.spark.sql.connect.planner.SparkConnectPlanner.$anonfun$transformRelation$1(SparkConnectPlanner.scala:235)
# 	at org.apache.spark.sql.connect.service.SessionHolder.$anonfun$usePlanCache$3(SessionHolder.scala:477)
# 	at scala.Option.getOrElse(Option.scala:201)
# 	at org.apache.spark.sql.connect.service.SessionHolder.usePlanCache(SessionHolder.scala:476)
# 	at org.apache.spark.sql.connect.planner.SparkConnectPlanner.transformRelation(SparkConnectPlanner.scala:147)
# 	at org.apache.spark.sql.connect.execution.SparkConnectPlanExecution.handlePlan(SparkConnectPlanExecution.scala:74)
# 	at org.apache.spark.sql.connect.execution.ExecuteThreadRunner.handlePlan(ExecuteThreadRunner.scala:314)
# 	at org.apache.spark.sql.connect.execution.ExecuteThreadRunner.$anonfun$executeInternal$1(ExecuteThreadRunner.scala:225)
# 	at org.apache.spark.sql.connect.execution.ExecuteThreadRunner.$anonfun$executeInternal$1$adapted(ExecuteThreadRunner.scala:196)
# 	at org.apache.spark.sql.connect.service.SessionHolder.$anonfun$withSession$2(SessionHolder.scala:341)
# 	at org.apache.spark.sql.SparkSession.withActive(SparkSession.scala:804)
# 	at org.apache.spark.sql.connect.service.SessionHolder.$anonfun$withSession$1(SessionHolder.scala:341)
# 	at org.apache.spark.JobArtifactSet$.withActiveJobArtifactState(JobArtifactSet.scala:94)
# 	at org.apache.spark.sql.artifact.ArtifactManager.$anonfun$withResources$1(ArtifactManager.scala:112)
# 	at org.apache.spark.util.Utils$.withContextClassLoader(Utils.scala:186)
# 	at org.apache.spark.sql.artifact.ArtifactManager.withClassLoaderIfNeeded(ArtifactManager.scala:102)
# 	at org.apache.spark.sql.artifact.ArtifactManager.withResources(ArtifactManager.scala:111)
# 	at org.apache.spark.sql.connect.service.SessionHolder.withSession(SessionHolder.scala:340)
# 	at org.apache.spark.sql.connect.execution.ExecuteThreadRunner.executeInternal(ExecuteThreadRunner.scala:196)
# 	at org.apache.spark.sql.connect.execution.ExecuteThreadRunner.org$apache$spark$sql$connect$execution$ExecuteThreadRunner$$execute(ExecuteThreadRunner.scala:125)
# 	at org.apache.spark.sql.connect.execution.ExecuteThreadRunner$ExecutionThread.run(ExecuteThreadRunner.scala:347)

# %%
# 8. Time travel queries
print("\n=== Time Travel Queries ===")
# Read table at version 0
print("Version 0:")
spark.read.format("delta").option("versionAsOf", 0).load("/tmp/delta-tables/table2").show()
# Out:
# === Time Travel Queries ===
# Version 0:
# +---+-------+
# | id|   plan|
# +---+-------+
# |  1|Starter|
# |  2|    Pro|
# +---+-------+

# %%
print("\n=== Final Table State ===")
spark.read.format("delta").load("/tmp/delta-tables/table2").show()
deltaTable.history().select("version", "timestamp", "operation").show()
# Out:
# === Final Table State ===
# +---+----------+
# | id|      plan|
# +---+----------+
# |  3|Enterprise|
# |  1|   Starter|
# |  4|     Basic|
# |  2|       Pro|
# +---+----------+
# ---------------------------------------------------------------------------
# InvalidPlanInput                          Traceback (most recent call last)
# Cell In[10], line 3
#       1 print("\n=== Final Table State ===")
#       2 spark.read.format("delta").load("/tmp/delta-tables/table2").show()
# ----> 3 deltaTable.history().select("version", "timestamp", "operation").show()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pyspark\sql\connect\dataframe.py:1153, in DataFrame.show(self, n, truncate, vertical)
#    1152 def show(self, n: int = 20, truncate: Union[bool, int] = True, vertical: bool = False) -> None:
# -> 1153     print(self._show_string(n, truncate, vertical))
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pyspark\sql\connect\dataframe.py:906, in DataFrame._show_string(self, n, truncate, vertical)
#     889     except ValueError:
#     890         raise PySparkTypeError(
#     891             errorClass="NOT_BOOL",
#     892             messageParameters={
#    (...)    895             },
#     896         )
#     898 table, _ = DataFrame(
#     899     plan.ShowString(
#     900         child=self._plan,
#     901         num_rows=n,
#     902         truncate=_truncate,
#     903         vertical=vertical,
#     904     ),
#     905     session=self._session,
# --> 906 )._to_table()
#     907 return table[0][0].as_py()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pyspark\sql\connect\dataframe.py:1837, in DataFrame._to_table(self)
#    1835 def _to_table(self) -> Tuple["pa.Table", Optional[StructType]]:
#    1836     query = self._plan.to_proto(self._session.client)
# -> 1837     table, schema, self._execution_info = self._session.client.to_table(
#    1838         query, self._plan.observations
#    1839     )
#    1840     assert table is not None
#    1841     return (table, schema)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pyspark\sql\connect\client\core.py:981, in SparkConnectClient.to_table(self, plan, observations)
#     979 req = self._execute_plan_request_with_metadata()
#     980 req.plan.CopyFrom(plan)
# --> 981 table, schema, metrics, observed_metrics, _ = self._execute_and_fetch(req, observations)
#     983 # Create a query execution object.
#     984 ei = ExecutionInfo(metrics, observed_metrics)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pyspark\sql\connect\client\core.py:1697, in SparkConnectClient._execute_and_fetch(self, req, observations, self_destruct)
#    1694 properties: Dict[str, Any] = {}
#    1696 with Progress(handlers=self._progress_handlers, operation_id=req.operation_id) as progress:
# -> 1697     for response in self._execute_and_fetch_as_iterator(
#    1698         req, observations, progress=progress
#    1699     ):
#    1700         if isinstance(response, StructType):
#    1701             schema = response
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pyspark\sql\connect\client\core.py:1674, in SparkConnectClient._execute_and_fetch_as_iterator(self, req, observations, progress)
#    1672     raise kb
#    1673 except Exception as error:
# -> 1674     self._handle_error(error)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pyspark\sql\connect\client\core.py:1982, in SparkConnectClient._handle_error(self, error)
#    1980     self.thread_local.inside_error_handling = True
#    1981     if isinstance(error, grpc.RpcError):
# -> 1982         self._handle_rpc_error(error)
#    1983     raise error
#    1984 finally:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pyspark\sql\connect\client\core.py:2066, in SparkConnectClient._handle_rpc_error(self, rpc_error)
#    2057                 logger.info(
#    2058                     "Disabling plan compression for the session due to "
#    2059                     "CONNECT_INVALID_PLAN.CANNOT_PARSE error."
#    2060                 )
#    2061                 self._plan_compression_threshold, self._plan_compression_algorithm = (
#    2062                     -1,
#    2063                     "NONE",
#    2064                 )
# -> 2066             raise convert_exception(
#    2067                 info,
#    2068                 status.message,
#    2069                 self._fetch_enriched_error(info),
#    2070                 self._display_server_stack_trace(),
#    2071                 status_code,
#    2072             ) from None
#    2074     raise SparkConnectGrpcException(
#    2075         message=status.message,
#    2076         grpc_status_code=status_code,
#    2077     ) from None
#    2078 else:
#
# InvalidPlanInput: No handler found for extension
#
# JVM stacktrace:
# org.apache.spark.sql.connect.common.InvalidPlanInput
# 	at org.apache.spark.sql.connect.planner.SparkConnectPlanner.$anonfun$transformRelationPlugin$3(SparkConnectPlanner.scala:253)
# 	at scala.Option.getOrElse(Option.scala:201)
# 	at org.apache.spark.sql.connect.planner.SparkConnectPlanner.transformRelationPlugin(SparkConnectPlanner.scala:253)
# 	at org.apache.spark.sql.connect.planner.SparkConnectPlanner.$anonfun$transformRelation$1(SparkConnectPlanner.scala:235)
# 	at org.apache.spark.sql.connect.service.SessionHolder.$anonfun$usePlanCache$3(SessionHolder.scala:477)
# 	at scala.Option.getOrElse(Option.scala:201)
# 	at org.apache.spark.sql.connect.service.SessionHolder.usePlanCache(SessionHolder.scala:476)
# 	at org.apache.spark.sql.connect.planner.SparkConnectPlanner.transformRelation(SparkConnectPlanner.scala:147)
# 	at org.apache.spark.sql.connect.planner.SparkConnectPlanner.transformRelation(SparkConnectPlanner.scala:133)
# 	at org.apache.spark.sql.connect.planner.SparkConnectPlanner.transformProject(SparkConnectPlanner.scala:1501)
# 	at org.apache.spark.sql.connect.planner.SparkConnectPlanner.$anonfun$transformRelation$1(SparkConnectPlanner.scala:153)
# 	at org.apache.spark.sql.connect.service.SessionHolder.$anonfun$usePlanCache$3(SessionHolder.scala:477)
# 	at scala.Option.getOrElse(Option.scala:201)
# 	at org.apache.spark.sql.connect.service.SessionHolder.usePlanCache(SessionHolder.scala:476)
# 	at org.apache.spark.sql.connect.planner.SparkConnectPlanner.transformRelation(SparkConnectPlanner.scala:147)
# 	at org.apache.spark.sql.connect.planner.SparkConnectPlanner.transformRelation(SparkConnectPlanner.scala:133)
# 	at org.apache.spark.sql.connect.planner.SparkConnectPlanner.transformShowString(SparkConnectPlanner.scala:306)
# 	at org.apache.spark.sql.connect.planner.SparkConnectPlanner.$anonfun$transformRelation$1(SparkConnectPlanner.scala:150)
# 	at org.apache.spark.sql.connect.service.SessionHolder.$anonfun$usePlanCache$3(SessionHolder.scala:477)
# 	at scala.Option.getOrElse(Option.scala:201)
# 	at org.apache.spark.sql.connect.service.SessionHolder.usePlanCache(SessionHolder.scala:476)
# 	at org.apache.spark.sql.connect.planner.SparkConnectPlanner.transformRelation(SparkConnectPlanner.scala:147)
# 	at org.apache.spark.sql.connect.execution.SparkConnectPlanExecution.handlePlan(SparkConnectPlanExecution.scala:74)
# 	at org.apache.spark.sql.connect.execution.ExecuteThreadRunner.handlePlan(ExecuteThreadRunner.scala:314)
# 	at org.apache.spark.sql.connect.execution.ExecuteThreadRunner.$anonfun$executeInternal$1(ExecuteThreadRunner.scala:225)
# 	at org.apache.spark.sql.connect.execution.ExecuteThreadRunner.$anonfun$executeInternal$1$adapted(ExecuteThreadRunner.scala:196)
# 	at org.apache.spark.sql.connect.service.SessionHolder.$anonfun$withSession$2(SessionHolder.scala:341)
# 	at org.apache.spark.sql.SparkSession.withActive(SparkSession.scala:804)
# 	at org.apache.spark.sql.connect.service.SessionHolder.$anonfun$withSession$1(SessionHolder.scala:341)
# 	at org.apache.spark.JobArtifactSet$.withActiveJobArtifactState(JobArtifactSet.scala:94)
# 	at org.apache.spark.sql.artifact.ArtifactManager.$anonfun$withResources$1(ArtifactManager.scala:112)
# 	at org.apache.spark.util.Utils$.withContextClassLoader(Utils.scala:186)
# 	at org.apache.spark.sql.artifact.ArtifactManager.withClassLoaderIfNeeded(ArtifactManager.scala:102)
# 	at org.apache.spark.sql.artifact.ArtifactManager.withResources(ArtifactManager.scala:111)
# 	at org.apache.spark.sql.connect.service.SessionHolder.withSession(SessionHolder.scala:340)
# 	at org.apache.spark.sql.connect.execution.ExecuteThreadRunner.executeInternal(ExecuteThreadRunner.scala:196)
# 	at org.apache.spark.sql.connect.execution.ExecuteThreadRunner.org$apache$spark$sql$connect$execution$ExecuteThreadRunner$$execute(ExecuteThreadRunner.scala:125)
# 	at org.apache.spark.sql.connect.execution.ExecuteThreadRunner$ExecutionThread.run(ExecuteThreadRunner.scala:347)
