# %% [markdown]
# ## Tool definition

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain.tools import tool

@tool
def square_root(x: float) -> float:
    """Calculate the square root of a number"""
    return x ** 0.5

# %%
@tool("square_root")
def tool1(x: float) -> float:
    """Calculate the square root of a number"""
    return x ** 0.5

# %%
@tool("square_root", description="Calculate the square root of a number")
def tool1(x: float) -> float:
    return x ** 0.5

# %%
tool1.invoke({"x": 467})
# Out:
# 21.61018278497431

# %%
square_root.invoke({"x": 467})
# Out:
# 21.61018278497431

# %% [markdown]
# ## Adding to agents

# %%
from azure_openai_llm import create_azure_llm

llm = create_azure_llm()
# Out:
# Using chat deployment: lums-gpt-4.1-mini
# Endpoint: https://aoai-foundry-swc.openai.azure.com/
# API Version: 2025-01-01-preview

# %%
from langchain.agents import create_agent

agent = create_agent(llm, tools=[tool1],
    system_prompt="You are an arithmetic wizard. Use your tools to calculate the square root and square of any number."
)

# %%
from langchain.messages import HumanMessage

question = HumanMessage(content="What is the square root of 467?")

response = agent.invoke(
    {"messages": [question]}
)

print(response['messages'][-1].content)
# Out:
# The square root of 467 is approximately 21.61.

# %%
from pprint import pprint

pprint(response['messages'])
# Out:
# [HumanMessage(content='What is the square root of 467?', additional_kwargs={}, response_metadata={}, id='2bd5ad48-f6b3-4e94-a79b-fd638a1f606b'),
#  AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 15, 'prompt_tokens': 74, 'total_tokens': 89, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4.1-mini-2025-04-14', 'system_fingerprint': 'fp_b6f445fc1c', 'id': 'chatcmpl-DQo0RKSCySlL9ET2VAFwaXK0TWx6S', 'prompt_filter_results': [{'prompt_index': 0, 'content_filter_results': {'hate': {'filtered': False, 'severity': 'safe'}, 'jailbreak': {'filtered': False, 'detected': False}, 'self_harm': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'violence': {'filtered': False, 'severity': 'safe'}}}], 'finish_reason': 'tool_calls', 'logprobs': None, 'content_filter_results': {}}, id='lc_run--019d5700-2a32-7241-be40-49fc257acf55-0', tool_calls=[{'name': 'square_root', 'args': {'x': 467}, 'id': 'call_56fpwYO1oaSouW1lwTPpkCe1', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 74, 'output_tokens': 15, 'total_tokens': 89, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#  ToolMessage(content='21.61018278497431', name='square_root', id='a045eb15-837e-4c92-86d0-91a2d1a37780', tool_call_id='call_56fpwYO1oaSouW1lwTPpkCe1'),
#  AIMessage(content='The square root of 467 is approximately 21.61.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 15, 'prompt_tokens': 103, 'total_tokens': 118, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4.1-mini-2025-04-14', 'system_fingerprint': 'fp_b6f445fc1c', 'id': 'chatcmpl-DQo0SUbrMF4IMyTIjpjYAipY26KDM', 'prompt_filter_results': [{'prompt_index': 0, 'content_filter_results': {'hate': {'filtered': False, 'severity': 'safe'}, 'jailbreak': {'filtered': False, 'detected': False}, 'self_harm': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'violence': {'filtered': False, 'severity': 'safe'}}}], 'finish_reason': 'stop', 'logprobs': None, 'content_filter_results': {'hate': {'filtered': False, 'severity': 'safe'}, 'protected_material_code': {'filtered': False, 'detected': False}, 'protected_material_text': {'filtered': False, 'detected': False}, 'self_harm': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'violence': {'filtered': False, 'severity': 'safe'}}}, id='lc_run--019d5700-3362-7521-8bb0-3b8c4893a73f-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 103, 'output_tokens': 15, 'total_tokens': 118, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]

# %%
#Retrieve the tool calls from the LLM response
response["messages"][1].tool_calls
# Out:
# [{'name': 'square_root',
#   'args': {'x': 467},
#   'id': 'call_56fpwYO1oaSouW1lwTPpkCe1',
#   'type': 'tool_call'}]

# %% [markdown]
# <H2>Manual Invocation</h2>

# %%
# Equivalent to create_agent, but using the bind_tools method on the LLM

from pprint import pprint

llm_with_tools = llm.bind_tools(tools=[tool1])
query = "What is the square root of 900?"
response = llm_with_tools.invoke(query)
pprint(response.tool_calls)
# Out:
# [{'args': {'x': 900},
#   'id': 'call_zOJga2J1KjAvRrFkJMjsG6gk',
#   'name': 'square_root',
#   'type': 'tool_call'}]

# %%
#Equivalent to agent.invoke

from langchain_core.messages import ToolMessage

# 1. Get the response from the LLM (which contains tool_calls)
query = "What is the square root of 1000?"
ai_msg = llm_with_tools.invoke(query)

for tool_call in ai_msg.tool_calls:
    # Look up the actual function from our 'tools' list
    # (In a real app, you'd use a dictionary mapping names to functions)
    selected_tool = {"square_root": square_root}[tool_call["name"].lower()]
    
    # 3. Execute the function with the arguments provided by the LLM
    tool_output = selected_tool.invoke(tool_call["args"])
    
    # 4. Create a ToolMessage to send the result back to the LLM
    # This must include the tool_call_id so the LLM knows which request this satisfies
    tool_message = ToolMessage(
        content=str(tool_output), 
        tool_call_id=tool_call["id"]
    )

# 5. Feed the result back to the LLM so it can give a final natural language answer
final_response = llm_with_tools.invoke([ai_msg, tool_message])
print(final_response.content)
# Out:
# The square root of 1000 is approximately 31.62.
