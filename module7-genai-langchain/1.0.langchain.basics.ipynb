# %% [markdown]
# ## Environment Variables Setup (Required)
#
# ### Set in Terminal/PowerShell (Temporary - current session only)
# ```bash
# # Windows PowerShell
# $env:AZURE_OPENAI_API_KEY="your_api_key_here"
# $env:AZURE_OPENAI_ENDPOINT="https://your-resource-name.openai.azure.com/"
#
# # Windows Command Prompt
# set AZURE_OPENAI_API_KEY=your_api_key_here
# set AZURE_OPENAI_ENDPOINT=https://your-resource-name.openai.azure.com/
#
# # Linux/macOS
# export AZURE_OPENAI_API_KEY="your_api_key_here"
# export AZURE_OPENAI_ENDPOINT="https://your-resource-name.openai.azure.com/"
#
# ```
#
# ### Option: Use a `.env` file (Recommended)
# Create a `.env` file in your project root:
#
# ```env
# AZURE_OPENAI_API_KEY=your_api_key_here
# AZURE_OPENAI_ENDPOINT=https://your-resource-name.openai.azure.com/
# AZURE_OPENAI_API_VERSION=2023-03-15-preview
# ```
#
# Then ensure your notebook/script loads `.env` using `load_dotenv()` before creating the client.
# ```

# %%
import os
from dotenv import load_dotenv

load_dotenv()

print("Current environment variables:")
print(f"AZURE_OPENAI_API_KEY: {'SET' if os.getenv('AZURE_OPENAI_API_KEY') else 'NOT SET'}")
print(f"AZURE_OPENAI_ENDPOINT: {'SET' if os.getenv('AZURE_OPENAI_ENDPOINT') else 'NOT SET'}")
print(f"AZURE_OPENAI_API_VERSION: {'SET' if os.getenv('AZURE_OPENAI_API_VERSION') else 'NOT SET'}")
# Out:
# Current environment variables:
# AZURE_OPENAI_API_KEY: SET
# AZURE_OPENAI_ENDPOINT: SET
# AZURE_OPENAI_API_VERSION: SET

# %% [markdown]
# ### 1. Development using LLM Native API

# %%
from openai import AzureOpenAI
from dotenv import load_dotenv  

load_dotenv()  # if using .env for configuration

client = AzureOpenAI(api_version="2023-03-15-preview")  # expects OPENAI_API_KEY in your environment

topic = "LangChain"
response = client.chat.completions.create(
    model="lums-gpt-4.1-mini",
    temperature=0,
    messages=[
        {"role": "user", "content": f"Explain {topic} in 3 short bullet points."}
    ],
)

result = response.choices[0].message.content
print(result)
# Out:
# - LangChain is a framework designed to simplify building applications with large language models (LLMs) by enabling easy integration of various components like prompts, chains, and memory.
# - It supports connecting LLMs with external data sources, APIs, and tools to create more dynamic and context-aware applications.
# - LangChain facilitates modular and scalable development of complex workflows involving natural language understanding and generation.

# %% [markdown]
# ### 2. Developing using Langchain API

# %%
from langchain_openai import AzureChatOpenAI
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser

# OPENAI_API_KEY and OPENAI_API_VERSION should be set in your environment or .env file
llm = AzureChatOpenAI(model="lums-gpt-4.1-mini")

# Basic Example 1: call the chat model directly
msg = llm.invoke("What is Python in one sentence?")
print("Example 1:\n", msg.content, "\n")
# Out:
# Example 1:
#  Python is a high-level, interpreted programming language known for its simplicity, readability, and versatility across various application domains.

# %% [markdown]
# ### 3. Creating Basic Chain using Langchain Expression Language (LCEL)

# %%
# Basic Example 2: simple prompt + parser chain
prompt = ChatPromptTemplate.from_template(
    "Explain {topic} in 3 short bullet points."
)

chain = prompt | llm | StrOutputParser()

result = chain.invoke({"topic": "LangChain"})
print(result)
# Out:
# - LangChain is a framework designed to simplify building applications that use large language models (LLMs) by chaining together components like prompts, models, and memory.
# - It provides tools for managing complex workflows involving LLMs, such as document retrieval, question answering, and agent-based interactions.
# - LangChain supports integration with various data sources and APIs, enabling dynamic and context-aware language model applications.

# %%
# Basic Example 3: reuse your existing chain with different topics
for t in ["LangChain", "Prompt Engineering", "Vector Databases"]:
    print(f"Example 3 ({t}):")
    print(chain.invoke({"topic": t}))
    print("-" * 60)
# Out:
# Example 3 (LangChain):
# - LangChain is a framework designed to simplify building applications that integrate large language models (LLMs) with other data sources and tools.
# - It provides modular components for managing prompts, chains, memory, and agents to create complex, dynamic workflows.
# - LangChain helps developers build applications like chatbots, data analysis tools, and automated agents that leverage LLM capabilities effectively.
# ------------------------------------------------------------
# Example 3 (Prompt Engineering):
# - Designing clear, specific inputs to guide AI models toward desired outputs.
# - Iteratively refining prompts to improve accuracy and relevance of responses.
# - Leveraging understanding of model behavior to optimize communication with AI systems.
# ------------------------------------------------------------
# Example 3 (Vector Databases):
# - **Storage & Retrieval:** Vector databases store data as high-dimensional vectors, enabling efficient similarity search based on vector distances.
# - **Use Cases:** Commonly used for applications like image recognition, natural language search, and recommendation systems where semantic similarity matters.
# - **Performance:** Optimized for fast approximate nearest neighbor (ANN) searches, handling large-scale datasets with low latency.
# ------------------------------------------------------------
