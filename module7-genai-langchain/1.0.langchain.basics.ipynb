# %%
from openai import AzureOpenAI
import os
from dotenv import load_dotenv  

load_dotenv()  # if using .env for configuration

client = AzureOpenAI(api_version="2023-03-15-preview")  # expects OPENAI_API_KEY in your environment

topic = "LangChain"
response = client.chat.completions.create(
    model="lums-gpt-4.1-mini",
    temperature=0,
    messages=[
        {"role": "user", "content": f"Explain {topic} in 3 short bullet points."}
    ],
)

result = response.choices[0].message.content
print(result)
# Out:
# - LangChain is a framework designed to simplify building applications with large language models (LLMs) by enabling easy integration of various components like prompts, chains, and memory.
# - It supports connecting LLMs with external data sources, APIs, and tools to create more dynamic and context-aware applications.
# - LangChain facilitates the development of complex workflows by chaining together multiple LLM calls and managing state across interactions.

# %%
from langchain_openai import AzureChatOpenAI
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser

# OPENAI_API_KEY and OPENAI_API_VERSION should be set in your environment or .env file
llm = AzureChatOpenAI(model="lums-gpt-4.1-mini")

# Basic Example 1: call the chat model directly
msg = llm.invoke("What is Python in one sentence?")
print("Example 1:\n", msg.content, "\n")
# Out:
# Example 1:
#  Python is a high-level, interpreted programming language known for its readability, simplicity, and versatility across various applications such as web development, data analysis, artificial intelligence, and automation.

# %%
# Basic Example 2: simple prompt + parser chain
prompt = ChatPromptTemplate.from_template(
    "Explain {topic} in 3 short bullet points."
)

chain = prompt | llm | StrOutputParser()

result = chain.invoke({"topic": "LangChain"})
print(result)
# Out:
# - LangChain is a framework designed to simplify building applications using large language models (LLMs) by chaining together various components like prompts, LLMs, and tools.
# - It supports integration with external data sources and APIs, enabling more dynamic and context-aware language model outputs.
# - LangChain facilitates the creation of complex workflows such as document question-answering, chatbots, and multi-step reasoning tasks.

# %%
# Basic Example 3: reuse your existing chain with different topics
for t in ["LangChain", "Prompt Engineering", "Vector Databases"]:
    print(f"Example 3 ({t}):")
    print(chain.invoke({"topic": t}))
    print("-" * 60)
# Out:
# Example 3 (LangChain):
# - LangChain is a framework designed to simplify building applications with large language models (LLMs) by providing modular components for prompt management, chaining, and memory.
# - It enables integration of LLMs with external data sources, APIs, and tools to create dynamic and context-aware applications.
# - LangChain supports workflows like document retrieval, question answering, agent-based automation, and conversational AI, enhancing the capabilities of LLM-powered apps.
# ------------------------------------------------------------
# Example 3 (Prompt Engineering):
# - Designing clear and specific inputs to guide AI models toward desired outputs.
# - Iteratively refining prompts based on model responses to improve accuracy and relevance.
# - Leveraging contextual cues and constraints to optimize AI performance in various tasks.
# ------------------------------------------------------------
# Example 3 (Vector Databases):
# - **Purpose:** Vector databases store and manage high-dimensional vector representations of data, enabling efficient similarity search and retrieval.
# - **Use Cases:** Commonly used in applications like recommendation systems, image and text search, and natural language processing.
# - **Functionality:** They support fast nearest neighbor searches using algorithms optimized for high-dimensional spaces, such as approximate nearest neighbor (ANN) methods.
# ------------------------------------------------------------
