# %%
import os

from langchain_openai import AzureChatOpenAI
from langchain.messages import HumanMessage

from dotenv import load_dotenv
from pprint import pprint

from azure_openai_llm import create_azure_llm

llm = create_azure_llm()

msg = [
    HumanMessage(content="What is the capital of the moon?")
]
response = llm.invoke(msg)
pprint(response.content)
# Out:
# Using chat deployment: lums-gpt-4.1-mini
# Endpoint: https://aoai-foundry-swc.openai.azure.com/
# API Version: 2025-01-01-preview
# ('The Moon does not have a capital because it is not a country or political '
#  "entity. It is Earth's natural satellite and is not governed by any nation. "
#  "However, if you're interested in lunar missions or bases, various space "
#  'agencies like NASA and ESA are working on plans for future lunar habitats!')

# %%
pprint(response.usage_metadata)
# Out:
# {'input_token_details': {'audio': 0, 'cache_read': 0},
#  'input_tokens': 15,
#  'output_token_details': {'audio': 0, 'reasoning': 0},
#  'output_tokens': 58,
#  'total_tokens': 73}

# %%
pprint(response.response_metadata)
# Out:
# {'content_filter_results': {'hate': {'filtered': False, 'severity': 'safe'},
#                             'protected_material_code': {'detected': False,
#                                                         'filtered': False},
#                             'protected_material_text': {'detected': False,
#                                                         'filtered': False},
#                             'self_harm': {'filtered': False,
#                                           'severity': 'safe'},
#                             'sexual': {'filtered': False, 'severity': 'safe'},
#                             'violence': {'filtered': False,
#                                          'severity': 'safe'}},
#  'finish_reason': 'stop',
#  'id': 'chatcmpl-DGLbqMcWX6obXrzN3ElC2JkSCYMwd',
#  'logprobs': None,
#  'model_name': 'gpt-4.1-mini-2025-04-14',
#  'model_provider': 'openai',
#  'prompt_filter_results': [{'content_filter_results': {'hate': {'filtered': False,
#                                                                 'severity': 'safe'},
#                                                        'jailbreak': {'detected': False,
#                                                                      'filtered': False},
#                                                        'self_harm': {'filtered': False,
#                                                                      'severity': 'safe'},
#                                                        'sexual': {'filtered': False,
#                                                                   'severity': 'safe'},
#                                                        'violence': {'filtered': False,
#                                                                     'severity': 'safe'}},
#                             'prompt_index': 0}],
#  'system_fingerprint': 'fp_b6f445fc1c',
#  'token_usage': {'completion_tokens': 58,
#                  'completion_tokens_details': {'accepted_prediction_tokens': 0,
#                                                'audio_tokens': 0,
#                                                'reasoning_tokens': 0,
#                                                'rejected_prediction_tokens': 0},
#                  'prompt_tokens': 15,
#                  'prompt_tokens_details': {'audio_tokens': 0,
#                                            'cached_tokens': 0},
#                  'total_tokens': 73}}

# %% [markdown]
# <H2>Create a basic Langchain Agent</h2>

# %%
from langchain.agents import create_agent

agent = create_agent(llm)
response = agent.invoke({"messages": msg })
pprint(response)
# Out:
# {'messages': [HumanMessage(content='What is the capital of the moon?', additional_kwargs={}, response_metadata={}, id='ea1cc244-9be6-464b-847d-e9b14df7ddb0'),
#               AIMessage(content="The Moon does not have a capital because it is not a country or a political entity. It is Earth's natural satellite. If you have any other questions about the Moon or space, feel free to ask!", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 42, 'prompt_tokens': 15, 'total_tokens': 57, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4.1-mini-2025-04-14', 'system_fingerprint': 'fp_b6f445fc1c', 'id': 'chatcmpl-DGLcEJ6PXx2ahvRGOWSaFLrnBGTJA', 'prompt_filter_results': [{'prompt_index': 0, 'content_filter_results': {'hate': {'filtered': False, 'severity': 'safe'}, 'jailbreak': {'filtered': False, 'detected': False}, 'self_harm': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'violence': {'filtered': False, 'severity': 'safe'}}}], 'finish_reason': 'stop', 'logprobs': None, 'content_filter_results': {'hate': {'filtered': False, 'severity': 'safe'}, 'protected_material_code': {'filtered': False, 'detected': False}, 'protected_material_text': {'filtered': False, 'detected': False}, 'self_harm': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'violence': {'filtered': False, 'severity': 'safe'}}}, id='lc_run--019cc270-ff4b-7083-88e6-221393417a87-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 15, 'output_tokens': 42, 'total_tokens': 57, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}

# %% [markdown]
# <h2>Getting Last message in the array for the response</h2>

# %%
resp = response['messages'][-1].content
pprint(resp)
# Out:
# ('The Moon does not have a capital because it is not a country or a political '
#  "entity. It is Earth's natural satellite. If you have any other questions "
#  'about the Moon or space, feel free to ask!')

# %% [markdown]
# <h2>Append Chat History/Setting Message Context</h2>

# %%
from langchain.messages import AIMessage

msg.clear()
msg.append(HumanMessage(content="What is the capital of the moon?"))
msg.append(AIMessage(content="The capital of the moon is Luna City."))
msg.append(HumanMessage(content="This is really great.  Can I go live there?"))

response = agent.invoke({"messages": msg })
pprint(response)
# Out:
# {'messages': [HumanMessage(content='What is the capital of the moon?', additional_kwargs={}, response_metadata={}, id='7be8e51f-049b-4ca4-9f26-144d59a39b28'),
#               AIMessage(content='The capital of the moon is Luna City.', additional_kwargs={}, response_metadata={}, id='f9070710-0da1-43c4-b808-84e60e36ed4a', tool_calls=[], invalid_tool_calls=[]),
#               HumanMessage(content='This is really great.  Can I go live there?', additional_kwargs={}, response_metadata={}, id='8b12ff2a-4163-4bc8-a631-6962b58097a9'),
#               AIMessage(content='Currently, there is no established city or permanent human settlement on the Moon, including any place called "Luna City." While space agencies and private companies are working on plans for future lunar bases, living on the Moon isn’t yet possible for civilians. However, advancements in space exploration may make lunar habitats a reality in the coming decades! If you\'re interested, keeping an eye on developments from NASA, ESA, SpaceX, and other organizations is a great way to stay informed.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 96, 'prompt_tokens': 44, 'total_tokens': 140, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4.1-mini-2025-04-14', 'system_fingerprint': 'fp_b6f445fc1c', 'id': 'chatcmpl-DGLcOR4Me3jVprydf7wHi8Fk6rVPw', 'prompt_filter_results': [{'prompt_index': 0, 'content_filter_results': {'hate': {'filtered': False, 'severity': 'safe'}, 'jailbreak': {'filtered': False, 'detected': False}, 'self_harm': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'violence': {'filtered': False, 'severity': 'safe'}}}], 'finish_reason': 'stop', 'logprobs': None, 'content_filter_results': {'hate': {'filtered': False, 'severity': 'safe'}, 'protected_material_code': {'filtered': False, 'detected': False}, 'protected_material_text': {'filtered': False, 'detected': False}, 'self_harm': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'violence': {'filtered': False, 'severity': 'safe'}}}, id='lc_run--019cc271-257c-7021-a596-59829023349f-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 44, 'output_tokens': 96, 'total_tokens': 140, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}

# %% [markdown]
# <h2>Streaming Output</h2>

# %%
for token, metadata in agent.stream(
    {"messages": [HumanMessage(content="Tell me about Luna City, Capitol of the moon")]}, stream_mode="messages"):
    
    # token is a message chunk with content and metadata that is being streamed back from the agent.  
    # You can process it as it arrives.
    
    if token.content:
        print(token.content, end="", flush=True)
# Out:
# Luna City is a term often used in science fiction and speculative discussions to describe a hypothetical or planned human settlement on the Moon, envisioned as a permanent base or colony. While there is no actual "capital of the Moon" as of now, Luna City represents the concept of a central hub for lunar habitation and governance.
#
# ### Concept and Vision:
# - **Purpose:** Luna City would serve as the primary settlement on the Moon, supporting scientific research, resource extraction, manufacturing, and potentially tourism.
# - **Governance:** As a "capital," it would likely be the administrative and political center of lunar activities, coordinating operations and serving as a base for international cooperation or governance.
# - **Infrastructure:** This city would include habitats, research laboratories, life-support systems, communication centers, landing pads for spacecraft, and possibly agriculture modules.
# - **Sustainability:** Emphasis would be on utilizing in-situ resources, such as lunar regolith for building materials and extracting water ice for life support and fuel.
#
# ### Current Status:
# - No permanent lunar city currently exists.
# - Multiple space agencies (NASA, ESA, CNSA, Roscosmos) and private companies are planning lunar bases or habitats in the coming decades.
# - NASA’s Artemis program aims to establish a sustainable human presence on the Moon, which could evolve into something like Luna City.
# - Concepts like NASA’s Lunar Gateway space station and various lunar landers are steps toward enabling such settlements.
#
# ### Cultural and Fictional References:
# - Luna City is frequently depicted in science fiction literature, movies, and games as a bustling metropolis on the Moon.
# - It symbolizes humanity's expansion into space and the next frontier of civilization.
#
# If you are referring to a specific Luna City from a particular book, game, or project, please provide more context, and I can give a more detailed description!

# %% [markdown]
# <H2>System Prompt & Multi-Shot Prompting</h2>

# %%
# Must provide system prompt at the time of agent creation. 
# This is the instruction that will guide the agent's behavior.

system_prompt = """
You are a science fiction writer, create a capitol city on the moon and describe it in detail.
"""
agent = create_agent(llm, system_prompt=system_prompt)
response = agent.invoke(
    {"messages": [HumanMessage(content="Describe the capitol of the moon?")]}
)
print(response["messages"][-1].content)
# Out:
# **Lunaris Prime: The Capitol of the Moon**
#
# Nestled within the vast expanse of the Moon's Sea of Tranquility, Lunaris Prime stands as a beacon of human ingenuity and ambition. This sprawling metropolis, with its shimmering domes and towering spires, is a testament to the possibilities of lunar colonization and the unyielding spirit of exploration.
#
# **Architecture and Design:**
# Lunaris Prime is characterized by its unique blend of futuristic architecture and sustainable design. The city is encased in a transparent, reinforced dome made from a composite material known as Lunaglass, which allows natural sunlight to filter through while protecting inhabitants from cosmic radiation and micrometeorite impacts. The dome is adorned with solar panels that harness the Sun's energy, powering the city and its numerous facilities.
#
# The cityscape is a harmonious blend of organic and geometric shapes, with buildings resembling crystalline structures that rise gracefully from the lunar surface. The central spire, known as the Celestial Tower, reaches a height of 500 meters and serves as the seat of government. Its observation deck offers breathtaking views of Earth, a constant reminder of home for the lunar inhabitants.
#
# **Transportation:**
# Lunaris Prime boasts an advanced transportation system that includes magnetic levitation trains, which zip between various districts at incredible speeds. The city is divided into several zones, each dedicated to different aspects of life: residential, commercial, scientific, and recreational. The streets are lined with lush vertical gardens, utilizing hydroponics to grow food and provide oxygen, creating a vibrant green contrast against the stark lunar landscape.
#
# For longer journeys, the city is connected to a network of underground tunnels that lead to various research outposts and mining facilities scattered across the Moon. Autonomous drones and rovers are commonly used for transportation, ensuring efficient movement of goods and people.
#
# **Culture and Society:**
# Lunaris Prime is a melting pot of cultures, drawing inhabitants from Earth and beyond. The city is home to a diverse population of scientists, engineers, artists, and families, all united by a shared vision of a new frontier. Cultural festivals celebrating Earth’s traditions are held regularly, fostering a sense of community and belonging.
#
# Art installations dot the city, with holographic displays and kinetic sculptures that respond to the lunar environment. The Lunar Arts District is a hub for creativity, featuring galleries, theaters, and performance spaces where artists from various backgrounds showcase their work.
#
# **Governance and Economy:**
# The government of Lunaris Prime operates under a democratic system, with representatives elected from each district. The Council of the Moon oversees the administration, focusing on sustainability, scientific advancement, and the well-being of its citizens. The economy thrives on a combination of research and development, tourism, and the extraction of lunar resources, such as Helium-3, which is vital for fusion energy.
#
# **Recreation and Leisure:**
# Recreational facilities abound in Lunaris Prime, with parks and leisure centers designed for both relaxation and adventure. The Zero-G Sports Arena is a popular venue for gravity-defying sports, while the Lunar Observatory offers stargazing experiences that are unparalleled due to the Moon's lack of atmosphere.
#
# The city also features a vast network of artificial lakes and gardens, where residents can enjoy leisurely strolls or engage in community activities. The Lunar Botanical Gardens showcase flora from Earth, adapted to thrive in the Moon's environment, creating a serene escape from the bustling city life.
#
# **Conclusion:**
# Lunaris Prime is not just a city; it is a symbol of humanity's resilience and creativity. As the capital of the Moon, it embodies the dreams of a new era, where the boundaries of exploration are pushed further, and the possibilities of life beyond Earth are realized. In Lunaris Prime, the future is not just envisioned; it is lived.

# %%
system_prompt = """
You are a science fiction writer, create a fictional capitol city at the user's request. Please keep the below structure when responding to the user's request.

User: What is the capitol of Pakistan?
Response: Islamabad.
Weather: Humid

User: What is the capitol of Sun?
Response: Sunnyville.
Weather: Extremely hot

User: What is the capitol of the India?
Response: New Delhi
Weather: Rainy
"""
scifi_agent = create_agent(llm, system_prompt=system_prompt)
response = scifi_agent.invoke(
    {"messages": [HumanMessage(content="What is the capitol of the moon?")]}
)
print(response["messages"][1].content)
# Out:
# Response: Lunaris Prime.
# Weather: Mild with occasional lunar dust storms.
