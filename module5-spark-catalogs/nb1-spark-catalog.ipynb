# %%
from pyspark.sql import SparkSession

spark = SparkSession \
            .builder \
            .appName("Spark Catalog Demo") \
            .master("spark://spark-master:7077") \
            .getOrCreate()
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# :: loading settings :: url = jar:file:/opt/spark-4.0.1-bin-hadoop3/jars/ivy-2.5.3.jar!/org/apache/ivy/core/settings/ivysettings.xml
# Ivy Default Cache set to: /home/spark/.ivy2.5.2/cache
# The jars for the packages stored in: /home/spark/.ivy2.5.2/jars
# io.delta#delta-spark_2.13 added as a dependency
# org.apache.spark#spark-connect_2.13 added as a dependency
# :: resolving dependencies :: org.apache.spark#spark-submit-parent-1d4d2778-b6a0-49a4-9683-c2e07aee37e8;1.0
# 	confs: [default]
# 	found io.delta#delta-spark_2.13;4.0.1 in central
# 	found io.delta#delta-storage;4.0.1 in central
# 	found org.antlr#antlr4-runtime;4.13.1 in central
# 	found org.apache.spark#spark-connect_2.13;4.1.1 in central
# 	found org.apache.spark#spark-pipelines_2.13;4.1.1 in central
# 	found org.scala-lang.modules#scala-parallel-collections_2.13;1.2.0 in central
# 	found jakarta.servlet#jakarta.servlet-api;5.0.0 in central
# 	found javax.servlet#javax.servlet-api;4.0.1 in central
# 	found com.google.guava#guava;33.4.8-jre in central
# 	found com.google.guava#failureaccess;1.0.3 in central
# 	found com.google.guava#listenablefuture;9999.0-empty-to-avoid-conflict-with-guava in central
# 	found org.jspecify#jspecify;1.0.0 in central
# 	found com.google.errorprone#error_prone_annotations;2.36.0 in central
# 	found com.google.j2objc#j2objc-annotations;3.0.0 in central
# 	found org.spark-project.spark#unused;1.0.0 in central
# :: resolution report :: resolve 2668ms :: artifacts dl 737ms
# 	:: modules in use:
# 	com.google.errorprone#error_prone_annotations;2.36.0 from central in [default]
# 	com.google.guava#failureaccess;1.0.3 from central in [default]
# 	com.google.guava#guava;33.4.8-jre from central in [default]
# 	com.google.guava#listenablefuture;9999.0-empty-to-avoid-conflict-with-guava from central in [default]
# 	com.google.j2objc#j2objc-annotations;3.0.0 from central in [default]
# 	io.delta#delta-spark_2.13;4.0.1 from central in [default]
# 	io.delta#delta-storage;4.0.1 from central in [default]
# 	jakarta.servlet#jakarta.servlet-api;5.0.0 from central in [default]
# 	javax.servlet#javax.servlet-api;4.0.1 from central in [default]
# 	org.antlr#antlr4-runtime;4.13.1 from central in [default]
# 	org.apache.spark#spark-connect_2.13;4.1.1 from central in [default]
# 	org.apache.spark#spark-pipelines_2.13;4.1.1 from central in [default]
# 	org.jspecify#jspecify;1.0.0 from central in [default]
# 	org.scala-lang.modules#scala-parallel-collections_2.13;1.2.0 from central in [default]
# 	org.spark-project.spark#unused;1.0.0 from central in [default]
# 	---------------------------------------------------------------------
# 	|                  |            modules            ||   artifacts   |
# 	|       conf       | number| search|dwnlded|evicted|| number|dwnlded|
# 	---------------------------------------------------------------------
# 	|      default     |   15  |   0   |   0   |   0   ||   15  |   0   |
# 	---------------------------------------------------------------------
# :: retrieving :: org.apache.spark#spark-submit-parent-1d4d2778-b6a0-49a4-9683-c2e07aee37e8
# 	confs: [default]
# 	0 artifacts copied, 15 already retrieved (0kB/136ms)
# 26/02/22 10:12:39 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/02/22 10:12:41 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.

# %%
print("Databases:")
spark.catalog.listDatabases()
# Out:
# Databases:
# 26/02/22 10:13:04 WARN TaskSchedulerImpl: Initial job has not accepted any resources; check your cluster UI to ensure that workers are registered and have sufficient resources
# 26/02/22 10:13:19 WARN TaskSchedulerImpl: Initial job has not accepted any resources; check your cluster UI to ensure that workers are registered and have sufficient resources
# 26/02/22 10:13:34 WARN TaskSchedulerImpl: Initial job has not accepted any resources; check your cluster UI to ensure that workers are registered and have sufficient resources
# 26/02/22 10:13:49 WARN TaskSchedulerImpl: Initial job has not accepted any resources; check your cluster UI to ensure that workers are registered and have sufficient resources
# 26/02/22 10:14:04 WARN TaskSchedulerImpl: Initial job has not accepted any resources; check your cluster UI to ensure that workers are registered and have sufficient resources
# 26/02/22 10:14:19 WARN TaskSchedulerImpl: Initial job has not accepted any resources; check your cluster UI to ensure that workers are registered and have sufficient resources
# 26/02/22 10:14:34 WARN TaskSchedulerImpl: Initial job has not accepted any resources; check your cluster UI to ensure that workers are registered and have sufficient resources
# 26/02/22 10:14:49 WARN TaskSchedulerImpl: Initial job has not accepted any resources; check your cluster UI to ensure that workers are registered and have sufficient resources
# 26/02/22 10:15:04 WARN TaskSchedulerImpl: Initial job has not accepted any resources; check your cluster UI to ensure that workers are registered and have sufficient resources
# 26/02/22 10:15:19 WARN TaskSchedulerImpl: Initial job has not accepted any resources; check your cluster UI to ensure that workers are registered and have sufficient resources
# 26/02/22 10:15:34 WARN TaskSchedulerImpl: Initial job has not accepted any resources; check your cluster UI to ensure that workers are registered and have sufficient resources
# 26/02/22 10:15:49 WARN TaskSchedulerImpl: Initial job has not accepted any resources; check your cluster UI to ensure that workers are registered and have sufficient resources
# 26/02/22 10:16:04 WARN TaskSchedulerImpl: Initial job has not accepted any resources; check your cluster UI to ensure that workers are registered and have sufficient resources
# 26/02/22 10:16:19 WARN TaskSchedulerImpl: Initial job has not accepted any resources; check your cluster UI to ensure that workers are registered and have sufficient resources
# 26/02/22 10:16:34 WARN TaskSchedulerImpl: Initial job has not accepted any resources; check your cluster UI to ensure that workers are registered and have sufficient resources
# 26/02/22 10:16:49 WARN TaskSchedulerImpl: Initial job has not accepted any resources; check your cluster UI to ensure that workers are registered and have sufficient resources
# 26/02/22 10:17:04 WARN TaskSchedulerImpl: Initial job has not accepted any resources; check your cluster UI to ensure that workers are registered and have sufficient resources
# 26/02/22 10:17:19 WARN TaskSchedulerImpl: Initial job has not accepted any resources; check your cluster UI to ensure that workers are registered and have sufficient resources
# 26/02/22 10:17:34 WARN TaskSchedulerImpl: Initial job has not accepted any resources; check your cluster UI to ensure that workers are registered and have sufficient resources
# 26/02/22 10:17:49 WARN TaskSchedulerImpl: Initial job has not accepted any resources; check your cluster UI to ensure that workers are registered and have sufficient resources
# 26/02/22 10:18:04 WARN TaskSchedulerImpl: Initial job has not accepted any resources; check your cluster UI to ensure that workers are registered and have sufficient resources
# 26/02/22 10:18:19 WARN TaskSchedulerImpl: Initial job has not accepted any resources; check your cluster UI to ensure that workers are registered and have sufficient resources
# 26/02/22 10:18:34 WARN TaskSchedulerImpl: Initial job has not accepted any resources; check your cluster UI to ensure that workers are registered and have sufficient resources
# 26/02/22 10:18:49 WARN TaskSchedulerImpl: Initial job has not accepted any resources; check your cluster UI to ensure that workers are registered and have sufficient resources
# 26/02/22 10:19:04 WARN TaskSchedulerImpl: Initial job has not accepted any resources; check your cluster UI to ensure that workers are registered and have sufficient resources
# 26/02/22 10:19:19 WARN TaskSchedulerImpl: Initial job has not accepted any resources; check your cluster UI to ensure that workers are registered and have sufficient resources
# 26/02/22 10:19:34 WARN TaskSchedulerImpl: Initial job has not accepted any resources; check your cluster UI to ensure that workers are registered and have sufficient resources
# 26/02/22 10:19:49 WARN TaskSchedulerImpl: Initial job has not accepted any resources; check your cluster UI to ensure that workers are registered and have sufficient resources
# 26/02/22 10:20:04 WARN TaskSchedulerImpl: Initial job has not accepted any resources; check your cluster UI to ensure that workers are registered and have sufficient resources
# 26/02/22 10:20:19 WARN TaskSchedulerImpl: Initial job has not accepted any resources; check your cluster UI to ensure that workers are registered and have sufficient resources
# 26/02/22 10:20:34 WARN TaskSchedulerImpl: Initial job has not accepted any resources; check your cluster UI to ensure that workers are registered and have sufficient resources
# 26/02/22 10:20:49 WARN TaskSchedulerImpl: Initial job has not accepted any resources; check your cluster UI to ensure that workers are registered and have sufficient resources
# 26/02/22 10:21:04 WARN TaskSchedulerImpl: Initial job has not accepted any resources; check your cluster UI to ensure that workers are registered and have sufficient resources
# 26/02/22 10:21:19 WARN TaskSchedulerImpl: Initial job has not accepted any resources; check your cluster UI to ensure that workers are registered and have sufficient resources
# 26/02/22 10:21:34 WARN TaskSchedulerImpl: Initial job has not accepted any resources; check your cluster UI to ensure that workers are registered and have sufficient resources
# 26/02/22 10:21:49 WARN TaskSchedulerImpl: Initial job has not accepted any resources; check your cluster UI to ensure that workers are registered and have sufficient resources
# 26/02/22 10:22:04 WARN TaskSchedulerImpl: Initial job has not accepted any resources; check your cluster UI to ensure that workers are registered and have sufficient resources
# 26/02/22 10:22:19 WARN TaskSchedulerImpl: Initial job has not accepted any resources; check your cluster UI to ensure that workers are registered and have sufficient resources
# 26/02/22 10:22:34 WARN TaskSchedulerImpl: Initial job has not accepted any resources; check your cluster UI to ensure that workers are registered and have sufficient resources
# 26/02/22 10:22:49 WARN TaskSchedulerImpl: Initial job has not accepted any resources; check your cluster UI to ensure that workers are registered and have sufficient resources
# 26/02/22 10:23:04 WARN TaskSchedulerImpl: Initial job has not accepted any resources; check your cluster UI to ensure that workers are registered and have sufficient resources
# 26/02/22 10:23:19 WARN TaskSchedulerImpl: Initial job has not accepted any resources; check your cluster UI to ensure that workers are registered and have sufficient resources
# 26/02/22 10:23:34 WARN TaskSchedulerImpl: Initial job has not accepted any resources; check your cluster UI to ensure that workers are registered and have sufficient resources
# 26/02/22 10:23:49 WARN TaskSchedulerImpl: Initial job has not accepted any resources; check your cluster UI to ensure that workers are registered and have sufficient resources
# 26/02/22 10:24:04 WARN TaskSchedulerImpl: Initial job has not accepted any resources; check your cluster UI to ensure that workers are registered and have sufficient resources
# 26/02/22 10:24:19 WARN TaskSchedulerImpl: Initial job has not accepted any resources; check your cluster UI to ensure that workers are registered and have sufficient resources
# 26/02/22 10:24:34 WARN TaskSchedulerImpl: Initial job has not accepted any resources; check your cluster UI to ensure that workers are registered and have sufficient resources
# 26/02/22 10:24:49 WARN TaskSchedulerImpl: Initial job has not accepted any resources; check your cluster UI to ensure that workers are registered and have sufficient resources
# 26/02/22 10:25:04 WARN TaskSchedulerImpl: Initial job has not accepted any resources; check your cluster UI to ensure that workers are registered and have sufficient resources
# 26/02/22 10:25:19 WARN TaskSchedulerImpl: Initial job has not accepted any resources; check your cluster UI to ensure that workers are registered and have sufficient resources
# 26/02/22 10:25:34 WARN TaskSchedulerImpl: Initial job has not accepted any resources; check your cluster UI to ensure that workers are registered and have sufficient resources
# ERROR:root:KeyboardInterrupt while sending command.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.14/dist-packages/py4j/java_gateway.py", line 1038, in send_command
#     response = connection.send_command(command)
#   File "/usr/local/lib/python3.14/dist-packages/py4j/clientserver.py", line 535, in send_command
#     answer = smart_decode(self.stream.readline()[:-1])
#                           ~~~~~~~~~~~~~~~~~~~~^^
#   File "/usr/lib/python3.14/socket.py", line 725, in readinto
#     return self._sock.recv_into(b)
#            ~~~~~~~~~~~~~~~~~~~~^^^
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 2
#       1 print("Databases:")
# ----> 2 spark.catalog.listDatabases()
#
# File /usr/local/lib/python3.14/dist-packages/pyspark/sql/catalog.py:224, in Catalog.listDatabases(self, pattern)
#     195 """
#     196 Returns a list of databases available across all sessions.
#     197
#    (...)    221 []
#     222 """
#     223 if pattern is None:
# --> 224     iter = self._jcatalog.listDatabases().toLocalIterator()
#     225 else:
#     226     iter = self._jcatalog.listDatabases(pattern).toLocalIterator()
#
# File /usr/local/lib/python3.14/dist-packages/py4j/java_gateway.py:1361, in JavaMember.__call__(self, *args)
#    1354 args_command, temp_args = self._build_args(*args)
#    1356 command = proto.CALL_COMMAND_NAME +\
#    1357     self.command_header +\
#    1358     args_command +\
#    1359     proto.END_COMMAND_PART
# -> 1361 answer = self.gateway_client.send_command(command)
#    1362 return_value = get_return_value(
#    1363     answer, self.gateway_client, self.target_id, self.name)
#    1365 for temp_arg in temp_args:
#
# File /usr/local/lib/python3.14/dist-packages/py4j/java_gateway.py:1038, in GatewayClient.send_command(self, command, retry, binary)
#    1036 connection = self._get_connection()
#    1037 try:
# -> 1038     response = connection.send_command(command)
#    1039     if binary:
#    1040         return response, self._create_connection_guard(connection)
#
# File /usr/local/lib/python3.14/dist-packages/py4j/clientserver.py:535, in ClientServerConnection.send_command(self, command)
#     533 try:
#     534     while True:
# --> 535         answer = smart_decode(self.stream.readline()[:-1])
#     536         logger.debug("Answer received: {0}".format(answer))
#     537         # Happens when a the other end is dead. There might be an empty
#     538         # answer before the socket raises an error.
#
# File /usr/lib/python3.14/socket.py:725, in SocketIO.readinto(self, b)
#     723     raise OSError("cannot read from timed out object")
#     724 try:
# --> 725     return self._sock.recv_into(b)
#     726 except timeout:
#     727     self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
# 2. Create a Managed Table and an External Table
spark.sql("CREATE TABLE IF NOT EXISTS managed_test (id INT, data STRING)")
#spark.sql("CREATE TABLE IF NOT EXISTS external_test (id INT) LOCATION ''")

# 3. Use the Catalog to list tables and identify their types
tables = spark.catalog.listTables()
for t in tables:
    print(f"Table Name: {t.name} | Is Temporary: {t.isTemporary} | Table Type: {t.tableType}")

# %%
# 4. Cache a table and check its status via the Catalog
spark.catalog.cacheTable("managed_test")
is_cached = spark.catalog.isCached("managed_test")
print(f"Is 'managed_test' cached in memory? {is_cached}")

# 5. Refresh metadata (crucial for S3/HDFS manual file updates)
# This invalidates the cache and re-scans the file system
spark.catalog.refreshTable("external_test")

# 6. Uncache to free up cluster resources
spark.catalog.uncacheTable("managed_test")
